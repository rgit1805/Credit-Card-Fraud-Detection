# %%
import pandas as pd

# %%
comparison = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest",
        "XGBoost"
    ],
    "Accuracy": [
        ...,
        ...,
        0.9996
    ],
    "Precision": [
        ...,
        ...,
        0.9487
    ],
    "Recall": [
        ...,
        ...,
        0.7789
    ],
    "F1 Score": [
        ...,
        ...,
        0.8555
    ],
    "ROC AUC": [
        ...,
        ...,
        0.9802
    ],
    "PR AUC": [
        ...,
        ...,
        0.8204
    ]
})

comparison
# Out:
#                  Model  Accuracy Precision    Recall  F1 Score   ROC AUC  \
# 0  Logistic Regression  Ellipsis  Ellipsis  Ellipsis  Ellipsis  Ellipsis
# 1        Random Forest  Ellipsis  Ellipsis  Ellipsis  Ellipsis  Ellipsis
# 2              XGBoost    0.9996    0.9487    0.7789    0.8555    0.9802
#
#      PR AUC
# 0  Ellipsis
# 1  Ellipsis
# 2    0.8204
